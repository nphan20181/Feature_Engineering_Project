# %% [markdown]
# # Importing Libraries

# %%
import tensorflow as tf
import keras
import numpy as np
import os
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras import models, regularizers, layers, optimizers, losses, metrics
from keras.models import Sequential
from keras.layers import Dense,Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Model,load_model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from sklearn.preprocessing import LabelEncoder
import itertools
import matplotlib.image as mpimg

# %% [markdown]
# # Creating dataset

# %%
def create_dataset(img_folder):
    img_data_array=[]
    class_name=[]
    for dirl in os.listdir(img_folder):
        for file in os.listdir(os.path.join(img_folder,dirl)):
            if any([file.endswith(x) for x in ['.jpeg', '.jpg']]):
                image_path=os.path.join(img_folder,dirl,file)
                image=plt.imread(image_path)
                image = cv2.resize(image, dsize=(180,180))
                img_data_array.append(image)
                class_name.append(dirl)
    return img_data_array,class_name

img_data, class_name =create_dataset('../input/flowers-recognition/flowers')

# %%
d = {'image_data':img_data,'class':class_name}
image_df = pd.DataFrame(d)
LE = LabelEncoder()
image_df['category'] = LE.fit_transform(image_df['class'])
image_df.tail()
# Out:
#                                              image_data class  category
# 4312  [[[130, 12, 22], [135, 10, 21], [142, 10, 21],...  rose         2
# 4313  [[[99, 100, 104], [85, 93, 81], [103, 107, 93]...  rose         2
# 4314  [[[17, 20, 25], [17, 20, 25], [13, 16, 23], [1...  rose         2
# 4315  [[[65, 82, 108], [66, 83, 109], [66, 83, 109],...  rose         2
# 4316  [[[164, 176, 169], [166, 179, 170], [167, 180,...  rose         2

# %%
plt.imshow(image_df['image_data'][4279])

# %% [markdown]
# # Applying Gabor Filter

# %%
gabor_features=[]
g_kernel = cv2.getGaborKernel((13, 13), 4.0, 56.2, 10.0, 1, 0, ktype=cv2.CV_32F)
for image in image_df['image_data']:
    gabor_feature = cv2.filter2D(image, cv2.CV_8UC3, g_kernel)
    gabor_features.append(gabor_feature)
image_df=image_df.assign(gabor = gabor_features)
image_df.head()
# Out:
#                                           image_data      class  category  \
# 0  [[[45, 44, 39], [45, 44, 39], [48, 46, 41], [4...  dandelion         1
# 1  [[[38, 30, 11], [35, 28, 9], [33, 27, 7], [27,...  dandelion         1
# 2  [[[158, 162, 163], [162, 166, 169], [159, 160,...  dandelion         1
# 3  [[[212, 199, 0], [210, 195, 0], [210, 191, 0],...  dandelion         1
# 4  [[[9, 12, 1], [9, 12, 1], [11, 14, 3], [11, 14...  dandelion         1
#
#                                                gabor
# 0  [[[147, 115, 111], [153, 128, 120], [168, 157,...
# 1  [[[255, 255, 120], [255, 255, 106], [255, 215,...
# 2  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3  [[[255, 255, 50], [255, 255, 42], [255, 255, 2...
# 4  [[[12, 32, 0], [17, 40, 0], [30, 59, 4], [45, ...

# %%
plt.imshow(image_df['gabor'][4279])

# %% [markdown]
# # Applying gaussian Filter

# %%
gauss_features=[]
for image in image_df['image_data']:
    gauss_feature = cv2.GaussianBlur(image, (3, 33), 0)
    gauss_features.append(gauss_feature)

image_df=image_df.assign(gauss = gauss_features)
image_df.head()
# Out:
#                                           image_data      class  category  \
# 0  [[[45, 44, 39], [45, 44, 39], [48, 46, 41], [4...  dandelion         1
# 1  [[[38, 30, 11], [35, 28, 9], [33, 27, 7], [27,...  dandelion         1
# 2  [[[158, 162, 163], [162, 166, 169], [159, 160,...  dandelion         1
# 3  [[[212, 199, 0], [210, 195, 0], [210, 191, 0],...  dandelion         1
# 4  [[[9, 12, 1], [9, 12, 1], [11, 14, 3], [11, 14...  dandelion         1
#
#                                                gabor  \
# 0  [[[147, 115, 111], [153, 128, 120], [168, 157,...
# 1  [[[255, 255, 120], [255, 255, 106], [255, 215,...
# 2  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3  [[[255, 255, 50], [255, 255, 42], [255, 255, 2...
# 4  [[[12, 32, 0], [17, 40, 0], [30, 59, 4], [45, ...
#
#                                                gauss
# 0  [[[47, 46, 43], [47, 47, 43], [48, 48, 45], [4...
# 1  [[[39, 31, 9], [38, 30, 9], [35, 28, 8], [30, ...
# 2  [[[161, 164, 167], [162, 164, 167], [162, 164,...
# 3  [[[219, 201, 3], [219, 200, 3], [216, 196, 2],...
# 4  [[[9, 11, 1], [10, 11, 2], [10, 12, 2], [11, 1...

# %%
plt.imshow(image_df['gauss'][4279])

# %% [markdown]
# # Applying Sharpning Filter

# %%
sharp_features=[]

skernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])

for image in image_df['image_data']:
    sharp_feature = cv2.filter2D(image, -1, skernel)
    sharp_features.append(sharp_feature)

image_df=image_df.assign(sharp = sharp_features)
image_df.head()
# Out:
#                                           image_data      class  category  \
# 0  [[[45, 44, 39], [45, 44, 39], [48, 46, 41], [4...  dandelion         1
# 1  [[[38, 30, 11], [35, 28, 9], [33, 27, 7], [27,...  dandelion         1
# 2  [[[158, 162, 163], [162, 166, 169], [159, 160,...  dandelion         1
# 3  [[[212, 199, 0], [210, 195, 0], [210, 191, 0],...  dandelion         1
# 4  [[[9, 12, 1], [9, 12, 1], [11, 14, 3], [11, 14...  dandelion         1
#
#                                                gabor  \
# 0  [[[147, 115, 111], [153, 128, 120], [168, 157,...
# 1  [[[255, 255, 120], [255, 255, 106], [255, 215,...
# 2  [[[255, 255, 255], [255, 255, 255], [255, 255,...
# 3  [[[255, 255, 50], [255, 255, 42], [255, 255, 2...
# 4  [[[12, 32, 0], [17, 40, 0], [30, 59, 4], [45, ...
#
#                                                gauss  \
# 0  [[[47, 46, 43], [47, 47, 43], [48, 48, 45], [4...
# 1  [[[39, 31, 9], [38, 30, 9], [35, 28, 8], [30, ...
# 2  [[[161, 164, 167], [162, 164, 167], [162, 164,...
# 3  [[[219, 201, 3], [219, 200, 3], [216, 196, 2],...
# 4  [[[9, 11, 1], [10, 11, 2], [10, 12, 2], [11, 1...
#
#                                                sharp
# 0  [[[41, 40, 29], [34, 34, 23], [55, 39, 31], [4...
# 1  [[[52, 40, 21], [32, 25, 7], [45, 31, 0], [23,...
# 2  [[[120, 128, 105], [155, 170, 167], [118, 104,...
# 3  [[[186, 191, 0], [168, 161, 0], [197, 188, 0],...
# 4  [[[9, 12, 1], [3, 6, 0], [17, 20, 9], [11, 14,...

# %%
plt.imshow(image_df['sharp'][4279])

# %% [markdown]
# # Creating Training, Testing and Validation Datasets using Gabor Images

# %%
x, x_test, y, y_test = train_test_split(image_df['gabor'].to_list(),image_df['category'].to_list(),test_size=0.2,train_size=0.8)
x_train, x_val, y_train, y_val = train_test_split(x,y,test_size = 0.25,train_size =0.75)


x_train=np.asarray(x_train)
y_train=np.asarray(y_train)
x_test=np.asarray(x_test)
y_test=np.asarray(y_test)
x_val=np.asarray(x_val)
y_val=np.asarray(y_val)

# %% [markdown]
# # Creating a CNN

# %%
model = Sequential()
model.add(Conv2D(filters = 1024, kernel_size = 3, padding = 'same', activation = 'relu', input_shape = (180,180,3)))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 512, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 256, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = 2))
model.add(Flatten())
model.add(Dense(1024, activation = 'relu'))
model.add(Dense(512, activation = 'relu'))
model.add(Dense(256, activation = 'relu'))
model.add(Dense(128, activation = 'relu'))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(5, activation = 'softmax'))

from tensorflow.keras.optimizers import RMSprop,SGD,Adam
adam=Adam(learning_rate=1e-4)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics = ['acc'])

print(model.summary())
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# 2021-11-12 00:15:29.026054: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:29.147759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:29.148577: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:29.149797: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-12 00:15:29.150999: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:29.151643: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:29.152306: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:31.121259: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:31.122061: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:31.122742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-12 00:15:31.123340: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 180, 180, 1024)    28672
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 1024)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 512)       4719104
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 512)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 256)       1179904
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 22, 22, 128)       295040
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 5, 5, 64)          73792
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 2, 2, 32)          18464
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              33792
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 7,195,877
# Trainable params: 7,195,877
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # Creating Checkpoints

# %%
reduce_learning_rate = ReduceLROnPlateau(monitor = 'val_acc', patience = 4, verbose = 1, factor = 0.3, min_lr = 0.0000001)
checkpoint = ModelCheckpoint('modelsharp.h5', monitor = 'val_acc', verbose = 1, save_best_only = True, mode = 'max')
early_stopping = EarlyStopping(monitor = 'val_loss', min_delta = 1e-10, patience = 10, verbose = 1, restore_best_weights = True)
callbacks = [reduce_learning_rate, checkpoint]

# %% [markdown]
# # Training Model

# %%
history = model.fit(x_train,y_train,
                    validation_data=(x_val,y_val),
                    epochs=50,
                    callbacks = callbacks,
                    batch_size=18)
# Out:
# 2021-11-12 00:15:34.586225: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 2021-11-12 00:15:36.235537: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 144/144 [==============================] - 61s 351ms/step - loss: 1.6198 - acc: 0.3009 - val_loss: 1.4347 - val_acc: 0.3727
#
# Epoch 00001: val_acc improved from -inf to 0.37269, saving model to modelsharp.h5
# Epoch 2/50
# 144/144 [==============================] - 47s 330ms/step - loss: 1.3689 - acc: 0.3874 - val_loss: 1.3032 - val_acc: 0.3611
#
# Epoch 00002: val_acc did not improve from 0.37269
# Epoch 3/50
# 144/144 [==============================] - 48s 330ms/step - loss: 1.3083 - acc: 0.4137 - val_loss: 1.4031 - val_acc: 0.3657
#
# Epoch 00003: val_acc did not improve from 0.37269
# Epoch 4/50
# 144/144 [==============================] - 48s 333ms/step - loss: 1.3063 - acc: 0.4040 - val_loss: 1.2880 - val_acc: 0.3773
#
# Epoch 00004: val_acc improved from 0.37269 to 0.37731, saving model to modelsharp.h5
# Epoch 5/50
# 144/144 [==============================] - 48s 333ms/step - loss: 1.2845 - acc: 0.4214 - val_loss: 1.3904 - val_acc: 0.3553
#
# Epoch 00005: val_acc did not improve from 0.37731
# Epoch 6/50
# 144/144 [==============================] - 48s 333ms/step - loss: 1.2947 - acc: 0.4218 - val_loss: 1.2772 - val_acc: 0.3819
#
# Epoch 00006: val_acc improved from 0.37731 to 0.38194, saving model to modelsharp.h5
# Epoch 7/50
# 144/144 [==============================] - 47s 330ms/step - loss: 1.2790 - acc: 0.4256 - val_loss: 1.2369 - val_acc: 0.4225
#
# Epoch 00007: val_acc improved from 0.38194 to 0.42245, saving model to modelsharp.h5
# Epoch 8/50
# 144/144 [==============================] - 48s 333ms/step - loss: 1.2347 - acc: 0.4496 - val_loss: 1.2173 - val_acc: 0.4444
#
# Epoch 00008: val_acc improved from 0.42245 to 0.44444, saving model to modelsharp.h5
# Epoch 9/50
# 144/144 [==============================] - 48s 333ms/step - loss: 1.2480 - acc: 0.4511 - val_loss: 1.3980 - val_acc: 0.3692
#
# Epoch 00009: val_acc did not improve from 0.44444
# Epoch 10/50
# 144/144 [==============================] - 47s 329ms/step - loss: 1.2214 - acc: 0.4500 - val_loss: 1.2003 - val_acc: 0.4560
#
# Epoch 00010: val_acc improved from 0.44444 to 0.45602, saving model to modelsharp.h5
# Epoch 11/50
# 144/144 [==============================] - 48s 332ms/step - loss: 1.2476 - acc: 0.4322 - val_loss: 1.3528 - val_acc: 0.3206
#
# Epoch 00011: val_acc did not improve from 0.45602
# Epoch 12/50
# 144/144 [==============================] - 47s 329ms/step - loss: 1.2038 - acc: 0.4604 - val_loss: 1.2252 - val_acc: 0.4444
#
# Epoch 00012: val_acc did not improve from 0.45602
# Epoch 13/50
# 144/144 [==============================] - 48s 332ms/step - loss: 1.1618 - acc: 0.4855 - val_loss: 1.2032 - val_acc: 0.4375
#
# Epoch 00013: val_acc did not improve from 0.45602
# Epoch 14/50
# 144/144 [==============================] - 48s 332ms/step - loss: 1.1256 - acc: 0.4971 - val_loss: 1.1812 - val_acc: 0.4479
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 00014: val_acc did not improve from 0.45602
# Epoch 15/50
# 144/144 [==============================] - 48s 333ms/step - loss: 1.0123 - acc: 0.5245 - val_loss: 1.1409 - val_acc: 0.4502
#
# Epoch 00015: val_acc did not improve from 0.45602
# Epoch 16/50
# 144/144 [==============================] - 47s 330ms/step - loss: 0.9078 - acc: 0.5821 - val_loss: 1.1854 - val_acc: 0.4803
#
# Epoch 00016: val_acc improved from 0.45602 to 0.48032, saving model to modelsharp.h5
# Epoch 17/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.8299 - acc: 0.6168 - val_loss: 1.2746 - val_acc: 0.5035
#
# Epoch 00017: val_acc improved from 0.48032 to 0.50347, saving model to modelsharp.h5
# Epoch 18/50
# 144/144 [==============================] - 47s 330ms/step - loss: 0.7576 - acc: 0.6655 - val_loss: 1.2149 - val_acc: 0.5324
#
# Epoch 00018: val_acc improved from 0.50347 to 0.53241, saving model to modelsharp.h5
# Epoch 19/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.6989 - acc: 0.7173 - val_loss: 1.2822 - val_acc: 0.5475
#
# Epoch 00019: val_acc improved from 0.53241 to 0.54745, saving model to modelsharp.h5
# Epoch 20/50
# 144/144 [==============================] - 47s 330ms/step - loss: 0.5949 - acc: 0.7536 - val_loss: 1.3798 - val_acc: 0.5220
#
# Epoch 00020: val_acc did not improve from 0.54745
# Epoch 21/50
# 144/144 [==============================] - 47s 329ms/step - loss: 0.5300 - acc: 0.7860 - val_loss: 1.4225 - val_acc: 0.5312
#
# Epoch 00021: val_acc did not improve from 0.54745
# Epoch 22/50
# 144/144 [==============================] - 47s 330ms/step - loss: 0.4898 - acc: 0.8100 - val_loss: 1.5037 - val_acc: 0.5567
#
# Epoch 00022: val_acc improved from 0.54745 to 0.55671, saving model to modelsharp.h5
# Epoch 23/50
# 144/144 [==============================] - 47s 330ms/step - loss: 0.4030 - acc: 0.8420 - val_loss: 1.8257 - val_acc: 0.5116
#
# Epoch 00023: val_acc did not improve from 0.55671
# Epoch 24/50
# 144/144 [==============================] - 48s 333ms/step - loss: 0.4172 - acc: 0.8440 - val_loss: 1.6418 - val_acc: 0.5475
#
# Epoch 00024: val_acc did not improve from 0.55671
# Epoch 25/50
# 144/144 [==============================] - 47s 330ms/step - loss: 0.3881 - acc: 0.8559 - val_loss: 1.7896 - val_acc: 0.5370
#
# Epoch 00025: val_acc did not improve from 0.55671
# Epoch 26/50
# 144/144 [==============================] - 48s 333ms/step - loss: 0.3185 - acc: 0.8895 - val_loss: 1.8048 - val_acc: 0.5278
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 00026: val_acc did not improve from 0.55671
# Epoch 27/50
# 144/144 [==============================] - 47s 329ms/step - loss: 0.2174 - acc: 0.9266 - val_loss: 2.0383 - val_acc: 0.5451
#
# Epoch 00027: val_acc did not improve from 0.55671
# Epoch 28/50
# 144/144 [==============================] - 47s 329ms/step - loss: 0.1486 - acc: 0.9567 - val_loss: 2.2288 - val_acc: 0.5417
#
# Epoch 00028: val_acc did not improve from 0.55671
# Epoch 29/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.1162 - acc: 0.9679 - val_loss: 2.4593 - val_acc: 0.5347
#
# Epoch 00029: val_acc did not improve from 0.55671
# Epoch 30/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0919 - acc: 0.9745 - val_loss: 2.6200 - val_acc: 0.5498
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 00030: val_acc did not improve from 0.55671
# Epoch 31/50
# 144/144 [==============================] - 48s 333ms/step - loss: 0.0673 - acc: 0.9830 - val_loss: 2.6902 - val_acc: 0.5417
#
# Epoch 00031: val_acc did not improve from 0.55671
# Epoch 32/50
# 144/144 [==============================] - 47s 329ms/step - loss: 0.0573 - acc: 0.9853 - val_loss: 2.8171 - val_acc: 0.5394
#
# Epoch 00032: val_acc did not improve from 0.55671
# Epoch 33/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0480 - acc: 0.9873 - val_loss: 2.8862 - val_acc: 0.5394
#
# Epoch 00033: val_acc did not improve from 0.55671
# Epoch 34/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0427 - acc: 0.9884 - val_loss: 2.9833 - val_acc: 0.5394
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 00034: val_acc did not improve from 0.55671
# Epoch 35/50
# 144/144 [==============================] - 47s 329ms/step - loss: 0.0385 - acc: 0.9900 - val_loss: 3.0253 - val_acc: 0.5440
#
# Epoch 00035: val_acc did not improve from 0.55671
# Epoch 36/50
# 144/144 [==============================] - 47s 329ms/step - loss: 0.0373 - acc: 0.9907 - val_loss: 3.0494 - val_acc: 0.5417
#
# Epoch 00036: val_acc did not improve from 0.55671
# Epoch 37/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0358 - acc: 0.9907 - val_loss: 3.0753 - val_acc: 0.5382
#
# Epoch 00037: val_acc did not improve from 0.55671
# Epoch 38/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0340 - acc: 0.9907 - val_loss: 3.0993 - val_acc: 0.5394
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
#
# Epoch 00038: val_acc did not improve from 0.55671
# Epoch 39/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0321 - acc: 0.9911 - val_loss: 3.1147 - val_acc: 0.5359
#
# Epoch 00039: val_acc did not improve from 0.55671
# Epoch 40/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0318 - acc: 0.9915 - val_loss: 3.1311 - val_acc: 0.5359
#
# Epoch 00040: val_acc did not improve from 0.55671
# Epoch 41/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0314 - acc: 0.9911 - val_loss: 3.1464 - val_acc: 0.5359
#
# Epoch 00041: val_acc did not improve from 0.55671
# Epoch 42/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0311 - acc: 0.9915 - val_loss: 3.1624 - val_acc: 0.5359
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
#
# Epoch 00042: val_acc did not improve from 0.55671
# Epoch 43/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0307 - acc: 0.9911 - val_loss: 3.1667 - val_acc: 0.5359
#
# Epoch 00043: val_acc did not improve from 0.55671
# Epoch 44/50
# 144/144 [==============================] - 47s 329ms/step - loss: 0.0306 - acc: 0.9915 - val_loss: 3.1713 - val_acc: 0.5359
#
# Epoch 00044: val_acc did not improve from 0.55671
# Epoch 45/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0305 - acc: 0.9911 - val_loss: 3.1761 - val_acc: 0.5359
#
# Epoch 00045: val_acc did not improve from 0.55671
# Epoch 46/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0304 - acc: 0.9915 - val_loss: 3.1811 - val_acc: 0.5359
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
#
# Epoch 00046: val_acc did not improve from 0.55671
# Epoch 47/50
# 144/144 [==============================] - 48s 333ms/step - loss: 0.0303 - acc: 0.9915 - val_loss: 3.1829 - val_acc: 0.5359
#
# Epoch 00047: val_acc did not improve from 0.55671
# Epoch 48/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0302 - acc: 0.9915 - val_loss: 3.1849 - val_acc: 0.5359
#
# Epoch 00048: val_acc did not improve from 0.55671
# Epoch 49/50
# 144/144 [==============================] - 47s 329ms/step - loss: 0.0302 - acc: 0.9915 - val_loss: 3.1867 - val_acc: 0.5359
#
# Epoch 00049: val_acc did not improve from 0.55671
# Epoch 50/50
# 144/144 [==============================] - 48s 332ms/step - loss: 0.0302 - acc: 0.9915 - val_loss: 3.1888 - val_acc: 0.5359
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 1e-07.
#
# Epoch 00050: val_acc did not improve from 0.55671

# %%
import matplotlib.pyplot as plt
  
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
accuracy = history_dict['acc']
val_accuracy = history_dict['val_acc']
  
epochs = range(1, len(loss_values) + 1)
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

ax[0].plot(epochs, accuracy, 'bo', label='Training accuracy')
ax[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
ax[0].set_title('Training & Validation Accuracy', fontsize=16)
ax[0].set_xlabel('Epochs', fontsize=16)
ax[0].set_ylabel('Accuracy', fontsize=16)
ax[0].legend()

ax[1].plot(epochs, loss_values, 'bo', label='Training loss')
ax[1].plot(epochs, val_loss_values, 'b', label='Validation loss')
ax[1].set_title('Training & Validation Loss', fontsize=16)
ax[1].set_xlabel('Epochs', fontsize=16)
ax[1].set_ylabel('Loss', fontsize=16)
ax[1].legend()

# %%
y_pred= np.argmax(model.predict(x_test),axis=1)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Oranges):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# # Testing Model

# %%
from sklearn.metrics import confusion_matrix
confusion_mtx = confusion_matrix(y_pred, y_test)
plot_confusion_matrix(confusion_mtx, classes = range(5))

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

test_loss, test_acc
# Out:
# 27/27 [==============================] - 3s 120ms/step - loss: 3.5678 - acc: 0.4873
# (3.5677831172943115, 0.48726850748062134)
